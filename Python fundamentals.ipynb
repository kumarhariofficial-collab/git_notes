# %% [markdown]
# # Number Guessing game Level 1

# %% [markdown]
# ## Level 1. Print if the user guest number is right or not

# %%
Secret_number = 56

# %%
User_input = input("Enter your Guess")
# Out:
# Enter your Guess 55

# %%
if Secret_number == User_input:
    print("Congratulations! you're guess is right!")
else:
    print("Sorry your guess is wrong")
# Out:
# Sorry your guess is wrong

# %%
Secret_number = "56"

User_input = input("Enter your Guess")

if Secret_number == User_input:
    print("Congratulations! you're guess is right!")
else:
    print("Sorry your guess is wrong")
# Out:
# Enter your Guess 56
# Congratulations! you're guess is right!

# %%
Secret_number = 56

User_input = int(input("Enter your Guess"))

if Secret_number == User_input:
    print("Congratulations! you're guess is right!")
else:
    print("Sorry your guess is wrong")
# Out:
# Enter your Guess 56
# Congratulations! you're guess is right!

# %% [markdown]
# ## Level 2. Print if the user guest number is right or not but with maximum of 7 tries

# %% [markdown]
# #### 2.1 Using for loop - end ietration number is defined

# %%
Secret_number = 56

for i in range(0,7):

    User_input = int(input("Enter your Guess"))
    
    if Secret_number == User_input:
        print("Congratulations! you're guess is right!")
        break
    else:
        print("Sorry your guess is wrong")
# Out:
# Enter your Guess 56
# Congratulations! you're guess is right!

# %% [markdown]
# #### 2.2 Using for while loop - When end number is not defined and the instructions has to  execute infinite times

# %%
Secret_number = 56

while True:
    User_input = int(input("Enter your Guess:"))
    
    if Secret_number == User_input:
        print("Congratulations! you're guess is right!")
        break
    else:
        print("Sorry your guess is wrong")
# Out:
# Enter your Guess: 56
# Congratulations! you're guess is right!

# %% [markdown]
# ## Level 3: Get multiple conditions
#
# 1. user should enter the number between 1:100. If it is entered wrong, the program should be, "Invalid number"
# 2. If the user guessed number  > secret number, then program should say, "your number is greater than the secret number"
# 3. If the user guessed number  < secret number, then program should say, "your number is lesser than the secret number"

# %%
print("Welcome to number guessing game!!!")
print("Guess the number Between 1 to 100")

Secret_number = 67

for i in range(1,8):
    user_input = int(input("Enter the number"))
    if user_input < 1 or user_input > 100:
        print("Invalid number! Please enter the number between 1-100")
    elif user_input > Secret_number:
        print("Your Number is Higher")
    elif user_input < Secret_number:
        print("Your number is lesser")
    else:
        print("Your Guessed number is correct")
        print(f"Congratulations, you have guessed the number {Secret_number} in {i} attemps")
        break
# Out:
# Welcome to number guessing game!!!
# Guess the number Between 1 to 100
# Enter the number ffgdfg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 7
#       4 Secret_number = 67
#       6 for i in range(1,8):
# ----> 7     user_input = int(input("Enter the number"))
#       8     if user_input < 1 or user_input > 100:
#       9         print("Invalid number! Please enter the number between 1-100")
#
# ValueError: invalid literal for int() with base 10: 'ffgdfg'

# %% [markdown]
# ## Level 4: Setting Multiple conditions

# %%
print("Welcome to number guessing game!!!")
print("Guess the number Between 1 to 100")

Secret_number = 67

for i in range(1,8):
    user_input = int(input("Enter the number"))
    if user_input < 1 or user_input > 100:
        print("Invalid number! Please enter the number between 1-100")
    elif user_input > Secret_number:
        print("Your Number is Higher")
    elif user_input < Secret_number:
        print("Your number is lesser")
    else:
        print("Your Guessed number is correct")
        break

if Secret_number == user_input:
    print(f"Congratulations, you have guessed the number {Secret_number} in {i} attemps")
else:
    print("Sorry! All your  trials is exceeded, Try Again!")
# Out:
# Welcome to number guessing game!!!
# Guess the number Between 1 to 100
# Enter the number 14
# Your number is lesser
# Enter the number 4
# Your number is lesser
# Enter the number 56
# Your number is lesser
# Enter the number 25
# Your number is lesser
# Enter the number 48
# Your number is lesser
# Enter the number 125
# Invalid number! Please enter the number between 1-100
# Enter the number 25
# Your number is lesser
# Sorry! All your  trials is exceeded, Try Again!

# %% [markdown]
# ## Level 5: The secret Number shouldn't be fixed. It should be random

# %%
import random

# %%
random.randint(1,100)
# Out:
# 47

# %%
import random

print("Welcome to number guessing game!!!")
print("Guess the number Between 1 to 100")

Secret_number = random.randint(1,100)

for i in range(1,8):
    user_input = int(input("Enter the number"))
    if user_input < 1 or user_input > 100:
        print("Invalid number! Please enter the number between 1-100")
    elif user_input > Secret_number:
        print("Your Number is Higher")
    elif user_input < Secret_number:
        print("Your number is lesser")
    else:
        print("Your Guessed number is correct")
        break

if Secret_number == user_input:
    print(f"Congratulations, you have guessed the number {Secret_number} in {i} attemps")
else:
    print("Sorry! All your  trials is exceeded, Try Again!")
# Out:
# Welcome to number guessing game!!!
# Guess the number Between 1 to 100
# Enter the number 65
# Your Number is Higher
# Enter the number 50
# Your number is lesser
# Enter the number 55
# Your number is lesser
# Enter the number 60
# Your Number is Higher
# Enter the number 58
# Your Number is Higher
# Enter the number 56
# Your Guessed number is correct
# Congratulations, you have guessed the number 56 in 6 attemps

# %% [markdown]
# ## Level 5 using while loop

# %%
import random

print("Welcome to number guessing game!!!")
print("Guess the number Between 1 to 100")

Secret_number = random.randint(1,100)

while True:
    user_input = int(input("Enter the number"))
    if user_input < 1 or user_input > 100:
        print("Invalid number! Please enter the number between 1-100")
    elif user_input > Secret_number:
        print("Your Number is Higher")
    elif user_input < Secret_number:
        print("Your number is lesser")
    else:
        print("Your Guessed number is correct")
        break
# Out:
# Welcome to number guessing game!!!
# Guess the number Between 1 to 100
# Enter the number 50
# Your number is lesser
# Enter the number 35
# Your number is lesser
# Enter the number 40
# Your number is lesser
# Enter the number 60
# Your number is lesser
# Enter the number 70
# Your Number is Higher
# Enter the number 65
# Your number is lesser
# Enter the number 66
# Your Guessed number is correct

# %% [markdown]
# ## Level 6 How to handle Invalid charcters or values.

# %%
import random

print("Welcome to number guessing game!!!")
print("Guess the number Between 1 to 100")

Secret_number = random.randint(1,100)

for i in range(1,8):
    try:
        user_input = int(input("Enter the number"))
        if user_input < 1 or user_input > 100:
            print("Invalid number! Please enter the number between 1-100")
        elif user_input > Secret_number:
            print("Your Number is Higher")
        elif user_input < Secret_number:
            print("Your number is lesser")
        else:
            print("Your Guessed number is correct")
            break
    except ValueError:
         print("Invalid characters, Not recognized. Please enter the number between 1-100 to play this game")

if Secret_number == user_input:
    print(f"Congratulations, you have guessed the number {Secret_number} in {i} attemps")
else:
    print("Sorry! All your  trials is exceeded, Try Again!")
# Out:
# Welcome to number guessing game!!!
# Guess the number Between 1 to 100
# Enter the number gfdhfh
# Invalid characters, Not recognized. Please enter the number between 1-100 to play this game
# Enter the number 60
# Your Number is Higher
# Enter the number 50
# Your Number is Higher
# Enter the number 40
# Your Number is Higher
# Enter the number 20
# Your Number is Higher
# Enter the number 10
# Your Number is Higher
# Enter the number 1
# Your number is lesser
# Sorry! All your  trials is exceeded, Try Again!

# %% [markdown]
# ## Level 7 Take this program to run as a function when it is called
#
# Step 1 - Define a function
# Step 2 - Call the function

# %%
def number_guessing_game():
    import random
    
    print("Welcome to number guessing game!!!")
    print("Guess the number Between 1 to 100")
    
    Secret_number = random.randint(1,100)
    
    for i in range(1,8):
        try:
            user_input = int(input("Enter the number"))
            if user_input < 1 or user_input > 100:
                print("Invalid number! Please enter the number between 1-100")
            elif user_input > Secret_number:
                print("Your Number is Higher")
            elif user_input < Secret_number:
                print("Your number is lesser")
            else:
                print("Your Guessed number is correct")
                break
        except ValueError:
             print("Invalid characters, Not recognized. Please enter the number between 1-100 to play this game")
    
    if Secret_number == user_input:
        print(f"Congratulations, you have guessed the number {Secret_number} in {i} attemps")
    else:
        print("Sorry! All your  trials is exceeded, Try Again!")

# %% [raw]
# Module two completed ------

# %%
number_guessing_game()
# Out:
# Welcome to number guessing game!!!
# Guess the number Between 1 to 100
# Enter the number
# Invalid characters, Not recognized. Please enter the number between 1-100 to play this game
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 number_guessing_game()
#
# Cell In[10], line 11, in number_guessing_game()
#       9 for i in range(1,8):
#      10     try:
# ---> 11         user_input = int(input("Enter the number"))
#      12         if user_input < 1 or user_input > 100:
#      13             print("Invalid number! Please enter the number between 1-100")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
#    1439     # re-raise KeyboardInterrupt, to truncate traceback
#    1440     msg = "Interrupted by user"
# -> 1441     raise KeyboardInterrupt(msg) from None
#    1442 except Exception:
#    1443     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
