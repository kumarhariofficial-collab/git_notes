# %% [markdown]
# # Task 1 All String functions

# %%
Company_name = "amazon development centre of india"
Job_position = "business analyst"
Expierence   = "5"

# %%
Company_name
# Out:
# 'amazon development centre of india'

# %%
print(Company_name, Job_position, Expierence)
# Out:
# amazon development centre of india business analyst 5

# %% [markdown]
# ## Swap case function

# %%
Company_name = "amazon development centre of india"
Job_position = "business ANALYST"
Expierence   = "5"

# %%
Job_position.swapcase()
# Out:
# 'BUSINESS analyst'

# %% [markdown]
# ## Title Function

# %%
Company_name.title()
# Out:
# 'Amazon Development Centre Of India'

# %%
Job_position.title()
# Out:
# 'Business Analyst'

# %% [markdown]
# ## Upper Function

# %%
Company_name.upper()
# Out:
# 'AMAZON DEVELOPMENT CENTRE OF INDIA'

# %%
Job_position.upper()
# Out:
# 'BUSINESS ANALYST'

# %% [markdown]
# ##  Capitalize Function

# %%
Company_name = "amazon"
Job_position = "business analyst"
Expierence   = "5.5"

# %%
Job_position.capitalize()
# Out:
# 'Business analyst'

# %%
Company_name = "amazon"
New_one = Company_name.capitalize()
print(f"New_word = {New_one} ")
# Out:
# New_word = Amazon

# %% [markdown]
# ## Strip Function

# %%
email_input = "  kumarhari736@gmail.com  "
clean_email = email_input.strip()
print(f"Original: {email_input} , Cleaned: {clean_email}")
# Out:
# Original:   kumarhari736@gmail.com   , Cleaned: kumarhari736@gmail.com

# %%
player_move = "  ROCK "
processed_move = player_move.strip()
print(f"Final Move: {processed_move}")
# Out:
# Final Move: ROCK

# %% [markdown]
# ## Split funtion

# %%
email = "kumarhari736@gmail.com" 
parts = email.split("@")
username = parts[1]
print(f"Username: {username}")
# Out:
# Username: gmail.com

# %%
email = "kumarhari736@gmail.com" 
parts = email.split("@")
username = parts[0]
print(f"Username: {username}")
# Out:
# Username: kumarhari736

# %% [markdown]
# ## Replace Function

# %%
Job_position = "business analyst"
New_role = Job_position.replace("business analyst" , "Data Analyst")
print(f"New Role  = {New_role}")
# Out:
# New Role  = Data Analyst

# %%
phone_number = "7010912351"
with_code = phone_number.replace("7010912351" , "(+91) 7010-912-351")
print(f"Contact: {with_code}")
# Out:
# Contact: (+91) 7010-912-351

# %% [markdown]
# ## Join Function

# %%
skills = "SQL", "Power BI", "Python"
skills_string = ", ".join(skills)
print(f"Technical Skills: {skills_string}")
# Out:
# Technical Skills: SQL, Power BI, Python

# %%
candiate_name = ("HARIKUMAR" ,"P")
full_name = " ".join(candiate_name)
print(f"Candidate:{full_name}")
# Out:
# Candidate:HARIKUMAR P

# %% [markdown]
# ## Find Function

# %%
education = "Electrical and Electronics Engineering"
place = education.find("and")
print(f"Position: {place}")
# Out:
# Position: 11

# %%
education = "Electrical and Electronics Engineering" 
place = education.find("B.E")
print(f"Position: {place}")
# Out:
# Position: -1

# %% [markdown]
# ## startswith() and endswith() Function

# %%
email = "kumarhari736@gmail.com" 
email.endswith("@gmail.com")
# Out:
# False

# %%
degree = "B.E Electrical and Electronics Engineering"
degree.startswith("if")
# Out:
# False

# %% [markdown]
# ## .isalpha(), .isdigit(), and .isalnum() Functions

# %%
phone = "7010912351"  
phone.isdigit()
# Out:
# True

# %%
player_name = "Hari123" 
player_name.isalpha()
# Out:
# False

# %%
player_name = "Hari123" 
player_name.isalnum()
# Out:
# True

# %% [markdown]
# ## Count function

# %%
job_titles = "ML DATA ASSOCIATE II, ML DATA ASSOCIATE I" 
count = job_titles.count("DATA")
print(f"The word 'Data' appears {count} times.")
# Out:
# The word 'Data' appears 2 times.

# %% [markdown]
# ## zfill Function

# %%
emp_id = "736"
emp_id.zfill(5)
# Out:
# '00736'

# %% [markdown]
# ## Partion Function

# %%
email = "kumarhari736@gmail.com"
user, sep, domain = email.partition("@")
print(f"User = {user} , Domain = {domain}")
# Out:
# User = kumarhari736 , Domain = gmail.com

# %%
input_data = "Player1:Rock"
player, sep, move = input_data.partition(":")
print(f"{player} chose {move}")
# Out:
# Player1 chose Rock

# %% [markdown]
# ## Lstrip & Rstip function

# %%
Company_name = "   amazon"
Job_position = " business analyst    "
Expierence   = "5"

# %%
Company_name.lstrip()
# Out:
# 'amazon'

# %%
Job_position.rstrip().lstrip()
# Out:
# 'business analyst'

# %% [markdown]
# ## Expandtabs function

# %%
bullet = "\tAnalyzed large volumes of data" 
print(bullet.expandtabs(5))
# Out:
#      Analyzed large volumes of data

# %%
data = "Python\tStatistics\tSQL\tExcel"
print(data.expandtabs(2))
# Out:
# Python  Statistics  SQL Excel

# %%
data = "Python\tStatistics\nSQL\tExcel"
print(data.expandtabs(10))
# Out:
# Python    Statistics
# SQL       Excel

# %% [markdown]
# ## Fromat Function

# %%
Name = "HARIKUMAR P"
Company_name ="Amazon"
Job_position = "KDP support Analyst"

# %%
print("My name is {}, and working in {} as {}".format(Name, Company_name, Job_position))
# Out:
# My name is HARIKUMAR P, and working in Amazon as KDP support Analyst

# %% [markdown]
# ##  IS space function

# %%
user_input = "     "
user_input.isspace()
# Out:
# True

# %% [markdown]
# ## Split lines

# %%
experience = "KDP Support Analyst\nML Data Associate II\nML Data Associate I"
roles = experience.splitlines()
print(f"Total Roles: {len(roles)}")
# Out:
# Total Roles: 3

# %% [markdown]
# ## Encode & decode

# %%
summary = "Highly motivated and results-oriented professional" 
encoded_summary = summary.encode('utf-8')
print(encoded_summary)
# Out:
# b'Highly motivated and results-oriented professional'

# %%
raw_data = b"Harikumar P"
decoded_name = raw_data.decode('utf-8')
print(decoded_name)
# Out:
# Harikumar P

# %% [markdown]
# ## Rsplit Function

# %%
filename = "Resume.pdf"
name, ext = filename.rsplit(".", 1)
print(f"File format: {ext}")
# Out:
# File format: pdf
