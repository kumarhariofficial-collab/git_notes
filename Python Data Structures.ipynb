# %% [markdown]
# ## Why Python Built-in Data Structures?
#
# * To collect multiple data in a structure.
#
# #### 4 Data Structures in python
# 1. List
# 2. Sets
# 3. Tuples
# 4. Dictionary - Key & Value pair

# %% [markdown]
# ## 1.List

# %%
student_marks = 67,78,10,100,90
student_marks
# Out:
# (67, 78, 10, 100, 90)

# %%
type(student_marks)
# Out:
# tuple

# %%
empty_cart = []

# %%
empty_cart
# Out:
# []

# %%
type(empty_cart)
# Out:
# list

# %%
items_to_buy = ["apples","Grapes","Mangoes","Banana","apples"] # accpets the duplicate
items_to_buy
# Out:
# ['apples', 'Grapes', 'Mangoes', 'Banana', 'apples']

# %%
type(items_to_buy)
# Out:
# list

# %%
items_to_buy = ["apples","Grapes","Mangoes","Banana","apples",6.68,10,7.78] #it collectes both String and float
items_to_buy
# Out:
# ['apples', 'Grapes', 'Mangoes', 'Banana', 'apples', 6.68, 10, 7.78]

# %%
len(items_to_buy) # how many items are there in that particular varibale
# Out:
# 8

# %%
items_to_buy[0] # Indexing - cutting the portion of whole value to get particular value.
# Out:
# 'apples'

# %%
items_to_buy[3]
# Out:
# 'Banana'

# %%
items_to_buy[-3]
# Out:
# 6.68

# %%
items_to_buy[0:3]
# Out:
# ['apples', 'Grapes', 'Mangoes']

# %%
items_to_buy[1:5 # Positive Indexing
# Out:
# ['Grapes', 'Mangoes', 'Banana', 'apples']

# %%
items_to_buy[-6:-3 #Negative Indexing
# Out:
# ['Mangoes', 'Banana', 'apples']

# %%
 items_to_buy
# Out:
# ['apples', 'Grapes', 'Mangoes', 'Banana', 'apples', 6.68, 10, 7.78]

# %%
 items_to_buy[5] = "watermelon" # mutubale which means to update the value or changing the value

# %%
 items_to_buy
# Out:
# ['apples', 'Grapes', 'Mangoes', 'Banana', 'apples', 'watermelon', 10, 7.78]

# %%
 items_to_buy[4]= "Orange"

# %%
 items_to_buy
# Out:
# ['apples', 'Grapes', 'Mangoes', 'Banana', 'Orange', 'watermelon', 10, 7.78]

# %% [markdown]
# # 2. Sets

# %%
empty_cart_2 = set()

# %%
empty_cart_2
# Out:
# set()

# %%
type(empty_cart_2)
# Out:
# set

# %%
items_to_buy_2 = {"apples","Grapes","Mangoes","Banana","apples"}

# %%
items_to_buy_2
# Out:
# {'Banana', 'Grapes', 'Mangoes', 'apples'}

# %%
type(items_to_buy_2)
# Out:
# set

# %%
items_to_buy_2 = {"Apples","Grapes","Mangoes","Banana","Apples",6.68,10,7.78}

# %%
items_to_buy_2
# Out:
# {10, 6.68, 7.78, 'Apples', 'Banana', 'Grapes', 'Mangoes'}

# %%
items_to_buy_2.add("Orange") # to add the value

# %%
items_to_buy_2
# Out:
# {'Onion'}

# %%
items_to_buy_2.discard("Grapes") #to remove the

# %%
items_to_buy_2
# Out:
# {10, 6.68, 7.78, 'Apples', 'Banana', 'Mangoes', 'Orange'}

# %%
items_to_buy_2.difference(items_to_buy)
# Out:
# {6.68, 'Apples'}

# %%
items_to_buy_2.clear()

# %%
items_to_buy_2
# Out:
# set()

# %%
items_to_buy_2.update({"Onion"})

# %%
items_to_buy_2
# Out:
# {'Onion'}

# %%
items_to_buy_2
# Out:
# {'Onion'}

# %%
items_to_buy_2 = {"Apples","Grapes","Mangoes","Banana","Apples",6.68,10,7.78}

# %% [markdown]
# # 3. Tuple

# %%
empty_cart_3 = () #empty Tuple

# %%
empty_cart_3
# Out:
# ()

# %%
type(empty_cart_3)
# Out:
# tuple

# %%
items_to_buy_3 = ("apples","Grapes","Mangoes","Banana","apples",6.8,8,9)

# %%
items_to_buy_3
# Out:
# ('apples', 'Grapes', 'Mangoes', 'Banana', 'apples', 6.8, 8, 9)

# %%
items_to_buy_3[0]
# Out:
# 'apples'

# %%
items_to_buy_3[0:4]
# Out:
# ('apples', 'Grapes', 'Mangoes', 'Banana')

# %%
items_to_buy_3.count("apples") #how many times repeat in the value
# Out:
# 2

# %%
items_to_buy_3.index("Grapes") # In which position the particular value stored
# Out:
# 1

# %% [markdown]
# # 4. Dictionary (It is a key value pair)

# %%
empty_cart_4 = {}
empty_cart_4
# Out:
# {}

# %%
type(empty_cart_4 )
# Out:
# dict

# %%
student_marks = {"Maths" :89,
                 "English":90,
                "Scinece":100}

# %%
student_marks
# Out:
# {'Maths': 89, 'English': 90, 'Scinece': 100}

# %%
type(student_marks)
# Out:
# dict

# %%
items_to_buy_4 = {"potato":5, "Toamato":2,"Apple":3}
items_to_buy_4
# Out:
# {'potato': 5, 'Toamato': 2, 'Apple': 3}

# %%
type(items_to_buy_4)
# Out:
# dict

# %%
items_to_buy_4 = {"potato":5, "Toamato":2,"Apple":3,"potato":6}
items_to_buy_4  # put Duplicate key but the latest value only derived in the output
# Out:
# {'potato': 6, 'Toamato': 2, 'Apple': 3}

# %%
items_to_buy_4.keys()
# Out:
# dict_keys(['potato', 'Toamato', 'Apple'])

# %%
items_to_buy_4.values()
# Out:
# dict_values([6, 2, 3])

# %%
import pandas as pd

# %%
pd.DataFrame(data=items_to_buy_4) # this one is not called due to this does not have any rows and column value and it is value error

# %%
math_student_marks = {"Class1":[67,68,90,100,87]} #expected after dictionary key more than one values then we need to use other data structure here we will use List[]
math_student_marks
# Out:
# {'Class1': [67, 68, 90, 100, 87]}

# %%
import pandas as pd

# %%
pd.DataFrame(math_student_marks)
# Out:
#    Class1
# 0      67
# 1      68
# 2      90
# 3     100
# 4      87

# %%
math_student_marks = {"Name":["Hari", "kalai", "priya", "hema", "Guna"],
                    "Maths":[67,68,90,100,87],
                     "Science":[100,90,60,40,89]}
math_student_marks
# Out:
# {'Name': ['Hari', 'kalai', 'priya', 'hema', 'Guna'],
#  'Maths': [67, 68, 90, 100, 87],
#  'Science': [100, 90, 60, 40, 89]}

# %%
pd.DataFrame(math_student_marks)
# Out:
#     Name  Maths  Science
# 0   Hari     67      100
# 1  kalai     68       90
# 2  priya     90       60
# 3   hema    100       40
# 4   Guna     87       89

# %% [markdown]
# # THE END of DATA Structures
